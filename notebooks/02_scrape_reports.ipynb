# %%
import os
os.chdir("..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore') 

from src.data.scrape_reports import scrape_pdf_reports, scrape_urls_responsibilityreports_website

# %%
pd.set_option("display.max_rows", 5)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 4. Scrape reports for refinitiv dataset

# %%
df_labeled_filenames = df_labeled

# %%
# Create new column to track scraping progress
df_labeled_filenames['CSR_Filename'] = ''

# Specify path to store the reports 
path_output = 'D:/master-thesis/data/pdf_reports_labeled/' # external harddrive

# %%
# Scrape reports
scrape_pdf_reports(df_labeled_filenames, path_output)
df_labeled_filenames
# Out:
#           ID Identifier              Company_Name          ISIN Ticker  \
# 0          0      888.L          888 Holdings PLC  GI000A0F6407    888
# 1          1        A.N  Agilent Technologies Inc  US00846U1016      A
# ...      ...        ...                       ...           ...    ...
# 10476  10476     YRI.TO           Yamana Gold Inc  CA98462Y1007    YRI
# 10477  10477      YUM.N           Yum! Brands Inc  US9884981013    YUM
#
#             Country_of_Exchange  Financial_Period_Absolute  \
# 0                United Kingdom                     2020.0
# 1      United States of America                     2020.0
# ...                         ...                        ...
# 10476                    Canada                     2010.0
# 10477  United States of America                     2010.0
#
#       Financial_Period_Relative  \
# 0                           FY0
# 1                           FY0
# ...                         ...
# 10476                     FY-10
# ...

# %%
# Store updated df to Excel
df_labeled_filenames.to_excel('data/interim/reports_labeled_filenames.xlsx', index=False)

# %%
# Only keep rows for which a report was scraped
df_labeled_filenames_clean = df_labeled_filenames[df_labeled_filenames['CSR_Filename'] != 'Error']
df_labeled_filenames_clean
# Out:
#           ID Identifier              Company_Name          ISIN Ticker  \
# 0          0      888.L          888 Holdings PLC  GI000A0F6407    888
# 1          1        A.N  Agilent Technologies Inc  US00846U1016      A
# ...      ...        ...                       ...           ...    ...
# 10469  10469      WPP.L                   WPP PLC  JE00B8KF9B49    WPP
# 10472  10472     WTRG.N   Essential Utilities Inc  US29670G1022   WTRG
#
#             Country_of_Exchange  Financial_Period_Absolute  \
# 0                United Kingdom                     2020.0
# 1      United States of America                     2020.0
# ...                         ...                        ...
# 10469            United Kingdom                     2010.0
# 10472  United States of America                     2010.0
#
#       Financial_Period_Relative  \
# 0                           FY0
# 1                           FY0
# ...                         ...
# 10469                     FY-10
# ...

# %%
# Remove files that are smaller than 100 (?) kb

# %%
# Store to Excel
df_labeled_filenames_clean.to_excel('data/interim/reports_labeled_filenames_clean.xlsx', index=False)

# %% [markdown]
# ## 6. Data exploration
