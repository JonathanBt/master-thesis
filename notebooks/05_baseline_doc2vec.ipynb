# %%
import os

os.chdir("..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import joblib
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings("ignore")

# Evaluation
from sklearn.metrics import (
    f1_score,
    classification_report,
    confusion_matrix,
    make_scorer
)

# doc2vec
import gensim
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
from sklearn import utils
from sklearn.base import BaseEstimator

# Other
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from skmultilearn.model_selection import IterativeStratification
from sklearn.preprocessing import MinMaxScaler

# Classifiers
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier

from src.models.evaluation import evaluation
from src.data.iterative_train_test_split import iterative_train_test_split

# %%
pd.set_option("display.max_rows", 5)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 100)

# %% [markdown]
# ## 1. Load and transform data

# %%
# Load data
df = pd.read_pickle("data/processed/reports_tokenized.p")
df
# Out:
#         ID Identifier                Company_Name          ISIN Ticker  \
# 0        0      888.L            888 Holdings PLC  GI000A0F6407    888
# 1        1        A.N    Agilent Technologies Inc  US00846U1016      A
# ...    ...        ...                         ...           ...    ...
# 8101  8101      ZBH.N  Zimmer Biomet Holdings Inc  US98956P1021    ZBH
# 8102  8102      ZBH.N  Zimmer Biomet Holdings Inc  US98956P1021    ZBH
#
#            Country_of_Exchange  Financial_Period_Absolute  \
# 0               United Kingdom                       2020
# 1     United States of America                       2020
# ...                        ...                        ...
# 8101  United States of America                       2016
# 8102  United States of America                       2015
#
#      Financial_Period_Relative  \
# 0                          FY0
# 1                          FY0
# ...                        ...
# 8101                      FY-4
# 8102                      FY-5
#
#                                                                                                CSR_URL  \
# 0                          https://corporate.888.com/wp-content/uploads/2021/04/2020-Annual-Report.pdf
# 1                 https://www.agilent.com/about/companyinfo/sustainability/Agilent-Report-CSR-2020.pdf
# ...                                                                                                ...
# 8101  https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/z/NYSE_ZBH_2016.pdf
# 8102  https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/z/NYSE_ZBH_2015.pdf
#
#       SDG_1  SDG_2  SDG_3  SDG_4  SDG_5  SDG_6  SDG_7  SDG_8  SDG_9  SDG_10  \
# 0     False  False   True   True   True   True   True   True  False     NaN
# 1     False  False   True   True   True   True   True   True  False     NaN
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 8101  False  False   True   True   True   True   True   True  False     NaN
# 8102  False  False   True   True  False   True   True  False  False     NaN
#
#       SDG_11  SDG_12  SDG_13  SDG_14  SDG_15  SDG_16  SDG_17  \
# 0      False    True    True     NaN   False    True   False
# 1      False    True    True     NaN    True    True   False
# ...      ...     ...     ...     ...     ...     ...     ...
# 8101   False    True   False     NaN   False    True   False
# 8102   False    True   False     NaN   False   False   False
#
#               CSR_Filename  \
# 0         0_888.L_2020.pdf
# 1           1_A.N_2020.pdf
# ...                    ...
# 8101  12676_ZBH.N_2016.pdf
# 8102  12677_ZBH.N_2015.pdf
#
#                                                                                                  CSR_Text  \
# 0     888 HOLDINGS PLC\n\nANNUAL REPORT & ACCOUNTS 2020\n\n
# A YEAR OF  \nSTRONG GROWTH \n\n888 IS ONE ...
# 1     Delivering on  \nour Promises\n\n2020 Corporate Social Responsibility Report\n\n1\n\n
# Letter fro...
# ...                                                                                                   ...
# 8101  E N V I R O N M E N T A L  \n\n \n\nS O C I A L  \n\nG O V E R N A N C E\n\nSustainability \nRep...
# 8102  E N V I R O N M E N T A L  \n\n \n\nS O C I A L  \n\nG O V E R N A N C E\n\nSustainability \nRep...
#
#                                                                                            CSR_Text_clean  \
# 0     888 ORG ANNUAL REPORT & ACCOUNTS 2020 A YEAR OF STRONG GROWTH ORG IS ONE OF THE WORLDS LEADING O...
# 1     Delivering on our Promises 2020 Corporate ORG 1 Letter from the President Stakeholder engagement...
# ...                                                                                                   ...
# 8101  E N V I R O N M E N T A L S O C I A L G O V E R N A N C E Sustainability Report 2016 T A B L E O...
# 8102  E N V I R O N M E N T A L S O C I A L G O V E R N A N C E Sustainability Report 2015 Investing n...
#
#                                                                                        CSR_Text_tokenized
# 0     org annual report account year strong growth org one world leading online betting gaming company...
# 1     delivering promise corporate org letter president stakeholder engagement environment table conte...
# ...                                                                                                   ...
# 8101  sustainability report company profile corporate overview purpose mission value sustainability co...
# 8102  sustainability report investing future world letter ceo stakeholder company profile corporate ov...
#
# [8103 rows x 30 columns]

# %%
# Transform labels to numpy array: Exclude SDGs 2 and 9 (too few aligned examples) and 10 and 14 (no mapping) -> 13 labels left
labels = [
    "SDG_1",
    "SDG_3",
    "SDG_4",
    "SDG_5",
    "SDG_6",
    "SDG_7",
    "SDG_8",
    "SDG_11",
    "SDG_12",
    "SDG_13",
    "SDG_15",
    "SDG_16",
    "SDG_17",
]
Y = df[labels].to_numpy().astype(int)

# %%
# Split into 70% training, 15% validation, and 15% test data (stratified for multi-label, adapted to work with df column)

np.random.seed(7)

X_train, Y_train, X_test, Y_test = iterative_train_test_split(df['CSR_Text_tokenized'], Y, test_size=0.3)
X_val, Y_val, X_test, Y_test = iterative_train_test_split(X_test, Y_test, test_size=0.5)

# %% [markdown]
# ## 2. Define doc2vec model
# Define a class with fit, transform, and fit_transform to be able to use the model in pipeline.
#
# Standard parameters:
# - dm=1: ‘distributed memory’ (PV-DM): Preserves the word order in a document
# - vector_size=100
# - window=5: The maximum distance between the current and predicted word within a sentence
# - negative=5: Negative sampling with 5 noise words
# - min_count=5: Ignores all words with total frequency lower than this
# - alpha=0.025: Initial learning rate
# - min_alpha=0.0001: Learning rate will linearly drop to min_alpha as training progresses
# - epochs=10: Number of iterations (epochs) over the corpus

# %%
class Doc2VecModel(BaseEstimator):

    def __init__(self, dm=1, vector_size=1, window=1, epochs=1):
        self.d2v_model = None
        self.vector_size = vector_size
        self.window = window
        self.dm = dm
        self.epochs = epochs

    def fit(self, raw_documents, y=None):
        # Initialize model
        self.d2v_model = Doc2Vec(vector_size=self.vector_size, window=self.window, dm=self.dm, epochs=self.epochs)
        # Tag docs
        tagged_documents = []
        for index, row in raw_documents.iteritems():
            tag = '{}_{}'.format("type", index)
            tokens = row.split()
            tagged_documents.append(TaggedDocument(words=tokens, tags=[tag]))
        # Build vocabulary
        self.d2v_model.build_vocab(tagged_documents)
        # Train model
        self.d2v_model.train(tagged_documents, total_examples=len(tagged_documents), epochs=self.d2v_model.epochs)
        return self

    def transform(self, raw_documents):
        X = []
        for index, row in raw_documents.iteritems():
            X.append(self.d2v_model.infer_vector(row.split()))
        X = pd.DataFrame(X, index=raw_documents.index)
        return X

    def fit_transform(self, raw_documents, y=None):
        self.fit(raw_documents)
        return self.transform(raw_documents)

# %% [markdown]
# ## 3. Replicate classification performed in NLP for SDGs paper
# Parameters:
# - dm=0: distributed bag of words (PV-DBOW)
# - vector_size=100
# - negative=5
# - epochs=30

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(dm=0, vector_size=100, window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('clf', SVC(kernel='linear'))
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__clf__C': [0.1, 1, 10] # Inverse of regularization strength, smaller values specify stronger regularization
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1) 
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_svm_paper = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_svm_paper.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_svm_paper.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_svm_paper.best_score_))
# Out:
# Best Parameters: {'estimator__clf__C': 10}
# Mean cross-validated F1-score of the best estimator: 0.7507685293472633

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(dm=0, vector_size=100, window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('clf', SVC(kernel='linear'))
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__clf__C': [10] # Inverse of regularization strength, smaller values specify stronger regularization
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=2, order=1) 
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_svm_paper = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_svm_paper.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_svm_paper.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_svm_paper.best_score_))
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   2 | elapsed: 295.7min remaining:    0.0s
# [Parallel(n_jobs=8)]: Done   2 out of   2 | elapsed: 295.7min finished
# [CV] estimator__clf__C=10 ............................................
# [CV] ............... estimator__clf__C=10, score=0.751, total=294.6min
# [CV] estimator__clf__C=10 ............................................
# [CV] ............... estimator__clf__C=10, score=0.749, total=295.7min

# %%
evaluation(grid_svm_paper, X_test, Y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2909671/3901171962.py in <module>
# ----> 1 evaluation(grid_svm_paper, X_test, Y_test)
#
# ~/master-thesis/src/models/evaluation.py in evaluation(model, X_test, Y_test)
#      19
#      20     # Compute predictions
# ---> 21     predictions = model.predict(X_test)
#      22
#      23     # Print classification report
#
# ~/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# ~/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/model_selection/_search.py in predict(self, X)
#     475         """
#     476         self._check_is_fitted('predict')
# --> 477         return self.best_estimator_.predict(X)
#     478
#     479     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/multiclass.py in predict(self, X)
#     331             indptr = array.array('i', [0])
#     332             for e in self.estimators_:
# --> 333                 indices.extend(np.where(_predict_binary(e, X) > thresh)[0])
#     334                 indptr.append(len(indices))
#     335             data = np.ones(len(indices), dtype=int)
#
# ~/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/multiclass.py in _predict_binary(estimator, X)
#      92         return estimator.predict(X)
#      93     try:
# ---> 94         score = np.ravel(estimator.decision_function(X))
#      95     except (AttributeError, NotImplementedError):
#      96         # probabilities of the positive class
#
# ~/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# ~/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/pipeline.py in decision_function(self, X)
#     488         Xt = X
#     489         for _, name, transform in self._iter(with_final=False):
# --> 490             Xt = transform.transform(Xt)
#     491         return self.steps[-1][-1].decision_function(Xt)
#     492
#
# /tmp/ipykernel_2909671/2483618505.py in transform(self, raw_documents)
#      26         X = []
#      27         for index, row in raw_documents.iteritems():
# ---> 28             X.append(self.d2v_model.infer_vector(row.split()))
#      29         X = pd.DataFrame(X, index=raw_documents.index)
#      30         return X
#
# ~/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/gensim/models/doc2vec.py in infer_vector(self, doc_words, alpha, min_alpha, epochs)
#     637         for i in range(epochs):
#     638             if self.sg:
# --> 639                 train_document_dbow(
#     640                     self, doc_words, doctag_indexes, alpha, work,
#     641                     learn_words=False, learn_hidden=False, doctag_vectors=doctag_vectors, doctags_lockf=doctags_lockf
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Classification with balanced weights

# %% [markdown]
# ### 4.1. Logistic Regression

# %%
np.random.seed(7)

# Pipeline
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('clf', OneVsRestClassifier(LogisticRegression(class_weight="balanced")))
])
    
# Parameters to test in Grid Search
parameters = {
    'doc2vec__dm': [0, 1],
    'doc2vec__vector_size': [100, 300, 500],
    'clf__estimator__C': [0.1, 1, 10] # Inverse of regularization strength, smaller values specify stronger regularization
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1)
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average="macro")

# Grid Search
grid_lr = GridSearchCV(pipeline, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_lr.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_lr.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_lr.best_score_))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.775 total time=35.6min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.815 total time=65.3min
# [CV 1/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.732 total time=67.4min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.753 total time=87.9min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.810 total time=68.5min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.730 total time=69.0min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.756 total time=91.3min
# [CV 3/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.815 total time=68.3min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.734 total time=67.2min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.751 total time=84.5min
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.759 total time=33.2min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.798 total time=48.6min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.717 total time=42.9min
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.742 total time=65.0min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.764 total time=35.1min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.792 total time=53.9min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.704 total time=45.5min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.720 total time=45.9min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.756 total time=90.6min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.795 total time=52.0min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.704 total time=45.2min
# [CV 2/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.740 total time=70.4min
# [CV 5/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.747 total time=82.8min
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Best Parameters: {'clf__estimator__C': 0.1, 'doc2vec__dm': 0, 'doc2vec__vector_size': 500}
# Mean cross-validated F1-score of the best estimator: 0.8113750651295829

# %%
np.random.seed(7)

# Pipeline
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('clf', OneVsRestClassifier(LogisticRegression(class_weight="balanced")))
])
    
# Parameters to test in Grid Search
parameters = {
    'doc2vec__dm': [0],
    'doc2vec__vector_size': [500],
    'clf__estimator__C': [0.1] # Inverse of regularization strength, smaller values specify stronger regularization
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=2, order=1)
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average="macro")

# Grid Search
grid_lr = GridSearchCV(pipeline, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_lr.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_lr.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_lr.best_score_))

# %%
evaluation(grid_lr, X_test, Y_test)

# %% [markdown]
# ### 4.2. Linear SVM

# %%
np.random.seed(7)

# Pipeline
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)),
    ('clf', OneVsRestClassifier(SVC(kernel='linear', class_weight="balanced")))
])
    
# Parameters to test in Grid Search
parameters = {
    'doc2vec__dm': [0, 1],
    'doc2vec__vector_size': [100, 300, 500],
    'clf__estimator__C': [0.1, 1, 10] # Inverse of regularization strength, smaller values specify stronger regularization
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1)
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average="macro")

# Grid Search
grid_svm = GridSearchCV(pipeline, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_svm.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_svm.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_svm.best_score_))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.752 total time=37.3min
# [CV 3/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.810 total time=63.7min
# [CV 1/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.723 total time=68.1min
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.736 total time=87.5min
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.758 total time=36.6min
# [CV 1/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.803 total time=63.9min
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.713 total time=44.8min
# [CV 3/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.740 total time=82.2min
# [CV 4/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.790 total time=50.9min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.709 total time=50.1min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.739 total time=74.5min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.747 total time=35.3min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.754 total time=34.7min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.791 total time=53.1min
# [CV 2/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.713 total time=56.2min
# [CV 3/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.745 total time=130.7min
# [CV 1/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.783 total time=51.7min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.809 total time=63.0min
# [CV 3/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.743 total time=68.2min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.749 total time=34.3min
# [CV 4/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.750 total time=34.3min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.792 total time=50.8min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.729 total time=50.8min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.739 total time=102.1min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.781 total time=53.8min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.810 total time=74.7min
# [CV 5/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.735 total time=134.0min
# [CV 3/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.794 total time=54.1min
# [CV 1/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.705 total time=42.2min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.713 total time=44.0min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.725 total time=86.0min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.782 total time=51.1min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.796 total time=70.3min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.726 total time=73.3min
# [CV 3/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.765 total time=34.8min
# [CV 2/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.778 total time=54.1min
# [CV 5/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.792 total time=72.9min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.734 total time=136.5min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.756 total time=37.2min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.801 total time=64.1min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.733 total time=67.6min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.738 total time=88.7min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.804 total time=64.6min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.718 total time=48.5min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.731 total time=104.4min
# [CV 5/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.793 total time=55.4min
# [CV 3/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.725 total time=60.3min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.737 total time=242.9min
# [CV 3/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.766 total time=36.2min
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.791 total time=49.9min
# [CV 3/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.725 total time=44.1min
# [CV 1/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.734 total time=88.0min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.784 total time=49.8min
# [CV 4/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.807 total time=71.0min
# [CV 4/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.731 total time=70.6min
# [CV 2/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.753 total time=34.0min
# [CV 5/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.757 total time=33.8min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.799 total time=70.5min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.707 total time=57.2min
# [CV 2/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.725 total time=232.3min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.798 total time=66.4min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.728 total time=76.0min
# [CV 4/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.744 total time=96.2min
# [CV 2/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.804 total time=74.6min
# [CV 5/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.716 total time=60.6min
# [CV 3/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.729 total time=217.4min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.758 total time=35.8min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.796 total time=48.8min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.709 total time=43.6min
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.731 total time=64.5min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.760 total time=33.9min
# [CV 3/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.793 total time=50.9min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.704 total time=48.7min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.729 total time=74.4min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.743 total time=99.0min
# [CV 3/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.809 total time=74.1min
# [CV 2/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.723 total time=129.1min
# [CV 5/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.734 total time=234.6min
# [CV 2/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.785 total time=53.8min
# [CV 5/5] END clf__estimator__C=0.1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.801 total time=61.7min
# [CV 4/5] END clf__estimator__C=0.1, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.736 total time=67.2min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.749 total time=34.8min
# [CV 5/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.757 total time=34.8min
# [CV 1/5] END clf__estimator__C=1, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.806 total time=66.2min
# [CV 4/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.712 total time=50.1min
# [CV 2/5] END clf__estimator__C=1, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.730 total time=95.4min
# [CV 3/5] END clf__estimator__C=10, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.796 total time=51.8min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.700 total time=56.1min
# [CV 1/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.730 total time=129.6min
# [CV 4/5] END clf__estimator__C=10, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.735 total time=239.5min
# Best Parameters: {'clf__estimator__C': 0.1, 'doc2vec__dm': 0, 'doc2vec__vector_size': 500}
# Mean cross-validated F1-score of the best estimator: 0.8049307287814449

# %%
np.random.seed(7)

# Pipeline
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)),
    ('clf', OneVsRestClassifier(SVC(kernel='linear', class_weight="balanced")))
])
    
# Parameters to test in Grid Search
parameters = {
    'doc2vec__dm': [0],
    'doc2vec__vector_size': [500],
    'clf__estimator__C': [0.1] # Inverse of regularization strength, smaller values specify stronger regularization
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=2, order=1)
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average="macro")

# Grid Search
grid_svm = GridSearchCV(pipeline, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_svm.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_svm.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_svm.best_score_))

# %%
evaluation(grid_svm, X_test, Y_test)

# %% [markdown]
# ### 4.3. Random Forest

# %%
np.random.seed(7)

# Pipeline
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('clf', OneVsRestClassifier(RandomForestClassifier(class_weight="balanced")))
])
    
# Parameters to test in Grid Search
parameters = {
    'doc2vec__dm': [0, 1],
    'doc2vec__vector_size': [100, 300, 500],
    'clf__estimator__n_estimators': [50, 100], # Number of trees in the forest
    'clf__estimator__max_depth': [10, 20, None] # Maximum depth of the tree
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1)
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average="macro")

# Grid Search
grid_rf = GridSearchCV(pipeline, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_rf.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_rf.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_rf.best_score_))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.827 total time=46.1min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.806 total time=73.7min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.837 total time=63.9min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.766 total time=126.5min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.841 total time=54.3min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.810 total time=95.6min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.847 total time=67.7min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.769 total time=125.7min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.775 total time=75.1min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.825 total time=58.2min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.820 total time=58.6min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.719 total time=109.5min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.820 total time=44.4min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.770 total time=85.0min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.836 total time=57.4min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.717 total time=111.4min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.768 total time=67.1min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.755 total time=78.8min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.743 total time=86.2min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.712 total time=86.2min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.763 total time=65.3min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.750 total time=68.4min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.846 total time=47.3min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.795 total time=94.3min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.811 total time=99.9min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.777 total time=126.3min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.811 total time=94.3min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.798 total time=99.5min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.771 total time=128.8min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.769 total time=103.8min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.764 total time=109.3min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.829 total time=57.4min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.778 total time=82.8min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.772 total time=84.5min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.768 total time=86.3min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.817 total time=46.0min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.768 total time=68.1min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.766 total time=82.5min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.752 total time=86.7min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.807 total time=32.3min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.767 total time=50.9min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.755 total time=64.5min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.742 total time=67.9min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.826 total time=47.1min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.809 total time=93.2min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.840 total time=70.8min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.757 total time=127.5min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.817 total time=75.8min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.841 total time=64.8min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.811 total time=98.1min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.810 total time=49.8min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.796 total time=55.4min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.786 total time=79.1min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.826 total time=72.1min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.716 total time=142.0min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.784 total time=83.2min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.830 total time=76.4min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.722 total time=132.2min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.764 total time=79.8min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.817 total time=68.3min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.764 total time=83.7min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.801 total time=33.5min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.784 total time=50.2min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.773 total time=65.3min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.764 total time=68.1min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.810 total time=72.5min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.832 total time=62.4min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.828 total time=66.6min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.772 total time=126.9min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.832 total time=76.0min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.810 total time=93.7min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.823 total time=99.3min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.799 total time=43.8min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.793 total time=79.2min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.776 total time=93.5min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.779 total time=86.0min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.820 total time=44.5min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.808 total time=42.9min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.777 total time=65.2min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.780 total time=82.5min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.778 total time=89.4min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.780 total time=55.4min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.765 total time=78.9min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.822 total time=68.9min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.717 total time=97.6min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.792 total time=35.1min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.774 total time=50.5min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.815 total time=43.5min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.711 total time=86.0min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.819 total time=71.2min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.802 total time=90.7min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.787 total time=100.5min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.849 total time=49.1min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.805 total time=75.8min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.796 total time=94.6min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.794 total time=99.5min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.816 total time=50.6min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.782 total time=79.0min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.777 total time=93.9min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.751 total time=85.5min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.727 total time=107.1min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.768 total time=85.1min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.815 total time=54.6min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.716 total time=110.6min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.791 total time=46.4min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.782 total time=66.6min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.820 total time=54.7min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.744 total time=77.5min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.802 total time=33.4min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.812 total time=34.9min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.767 total time=64.0min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.813 total time=44.2min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.706 total time=86.1min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.840 total time=46.6min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.800 total time=94.5min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.798 total time=97.8min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.759 total time=124.4min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.829 total time=73.9min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.840 total time=68.3min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.773 total time=123.5min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.816 total time=55.5min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.760 total time=102.9min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.825 total time=72.4min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.719 total time=141.4min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.785 total time=108.3min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.776 total time=97.9min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.796 total time=44.3min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.796 total time=45.8min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.749 total time=87.9min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.809 total time=57.3min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.710 total time=91.5min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.782 total time=51.9min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.817 total time=42.0min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.831 total time=42.8min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.712 total time=85.1min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.810 total time=70.4min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.792 total time=91.1min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.800 total time=98.9min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.824 total time=49.0min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.829 total time=53.9min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.807 total time=95.2min
# [CV 4/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.829 total time=66.7min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.775 total time=126.6min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.770 total time=80.8min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.836 total time=59.7min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.758 total time=85.3min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.711 total time=114.9min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.809 total time=65.2min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.835 total time=55.9min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.768 total time=86.0min
# [CV 4/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.722 total time=108.1min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.780 total time=83.6min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.824 total time=58.6min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.707 total time=88.7min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.766 total time=50.2min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.834 total time=42.3min
# [CV 1/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.748 total time=64.7min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.704 total time=83.3min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.838 total time=46.5min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.828 total time=73.8min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.844 total time=63.0min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.814 total time=101.6min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.835 total time=49.9min
# [CV 3/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.815 total time=75.7min
# [CV 1/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.830 total time=64.2min
# [CV 2/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.814 total time=97.1min
# [CV 5/5] END clf__estimator__max_depth=10, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.773 total time=128.9min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.777 total time=103.7min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.767 total time=109.1min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=100;, score=0.806 total time=57.3min
# [CV 2/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=300;, score=0.787 total time=82.8min
# [CV 1/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=100;, score=0.823 total time=63.4min
# [CV 3/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.765 total time=87.1min
# [CV 5/5] END clf__estimator__max_depth=20, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.738 total time=113.2min
# [CV 3/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.765 total time=83.2min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.757 total time=81.6min
# [CV 4/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=50, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.710 total time=86.0min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=0, doc2vec__vector_size=500;, score=0.761 total time=63.3min
# [CV 2/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=300;, score=0.759 total time=64.4min
# [CV 5/5] END clf__estimator__max_depth=None, clf__estimator__n_estimators=100, doc2vec__dm=1, doc2vec__vector_size=500;, score=0.719 total time=84.3min
# Best Parameters: {'clf__estimator__max_depth': 10, 'clf__estimator__n_estimators': 100, 'doc2vec__dm': 1, 'doc2vec__vector_size': 100}
# Mean cross-validated F1-score of the best estimator: 0.8375450726245541

# %%
np.random.seed(7)

# Pipeline
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('clf', OneVsRestClassifier(RandomForestClassifier(class_weight="balanced")))
])
    
# Parameters to test in Grid Search
parameters = {
    'doc2vec__dm': [1],
    'doc2vec__vector_size': [100],
    'clf__estimator__n_estimators': [100], # Number of trees in the forest
    'clf__estimator__max_depth': [10] # Maximum depth of the tree
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1)
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average="macro")

# Grid Search
grid_rf = GridSearchCV(pipeline, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_rf.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_rf.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_rf.best_score_))

# %%
evaluation(grid_rf, X_test, Y_test)

# %% [markdown]
# ## 5. Classification with SMOTE

# %% [markdown]
# ### 5.1. KNN

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('clf', KNeighborsClassifier())
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__doc2vec__dm': [0, 1],
    'estimator__doc2vec__vector_size': [100, 300, 500],
    'estimator__clf__n_neighbors': [5, 15, 25, 55] # Number of neighbors
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1) 
# Optimize for macro F1-score (same weight for each label)
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_knn = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_knn.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_knn.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_knn.best_score_))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.759, total=380.8min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.585, total=570.8min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.744, total=390.2min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.685, total=733.9min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.764, total=388.2min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.615, total=738.3min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.766, total=388.5min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.713, total=749.6min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.740, total=555.8min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.683, total=743.0min
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed: 1299.4min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.692, total=558.4min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.480, total=740.8min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.726, total=378.1min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.720, total=570.2min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.779, total=483.5min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.663, total=771.4min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.583, total=397.6min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.795, total=502.3min
# [CV] estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=5, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.573, total=1017.3min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.513, total=416.2min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.239, total=813.9min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.685, total=498.5min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.266, total=1033.3min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.118, total=563.8min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.629, total=501.7min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.630, total=509.3min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.280, total=637.2min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.677, total=519.3min
# [CV] estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=15, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.384, total=776.7min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.395, total=402.1min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.391, total=398.4min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.097, total=576.7min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.643, total=498.2min
# [CV] estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__n_neighbors=25, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.254, total=764.7min
# [CV] estimator__clf__n_neighbors=55, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__n_neighbors=55, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.213, total=444.8min

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('clf', KNeighborsClassifier())
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__doc2vec__dm': [0, 1],
    'estimator__doc2vec__vector_size': [100, 300, 500],
    'estimator__clf__n_neighbors': [5, 15, 25, 55] # Number of neighbors
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1) 
# Optimize for macro F1-score (same weight for each label)
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_knn = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_knn.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_knn.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_knn.best_score_))

# %%
evaluation(grid_knn, X_test, Y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.85      0.51       205
#            1       0.93      0.65      0.77      1483
#            2       0.89      0.58      0.70      1435
#            3       0.88      0.61      0.72      1311
#            4       0.94      0.63      0.75      1411
#            5       0.91      0.60      0.73      1309
#            6       0.87      0.62      0.73      1227
#            7       0.35      0.84      0.50       199
#            8       0.95      0.61      0.74      1528
#            9       0.85      0.54      0.66      1144
#           10       0.61      0.85      0.71       582
#           11       0.88      0.61      0.72      1251
#           12       0.38      0.86      0.52       199
#
#    micro avg       0.81      0.63      0.71     13284
#    macro avg       0.75      0.68      0.67     13284
# weighted avg       0.87      0.63      0.72     13284
#  samples avg       0.74      0.60      0.63     13284

# %% [markdown]
# ### 5.2. Naive Bayes

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('Normalizing', MinMaxScaler()),
    ('clf', MultinomialNB())
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__doc2vec__dm': [0, 1],
    'estimator__doc2vec__vector_size': [100, 300, 500],
    'estimator__clf__alpha': [0.01, 0.1, 1] # Additive (Laplace/Lidstone) smoothing parameter (0 for no smoothing)
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1) 
# Optimize for macro F1-score (same weight for each label)
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_nb = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_nb.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_nb.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_nb.best_score_))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed: 1202.0min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.739, total=347.7min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.736, total=532.1min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.682, total=435.2min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.731, total=352.7min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.727, total=684.0min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.685, total=454.4min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.746, total=517.3min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.725, total=671.3min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.711, total=683.0min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.730, total=385.9min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.735, total=370.3min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.702, total=695.1min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.730, total=382.1min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.744, total=543.4min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.682, total=463.9min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.704, total=907.6min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.739, total=558.4min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.684, total=463.9min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.742, total=522.4min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.690, total=467.0min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.687, total=464.8min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.703, total=933.2min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.741, total=532.0min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.731, total=710.7min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.702, total=968.8min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.735, total=348.7min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.732, total=543.6min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.686, total=456.7min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.706, total=908.0min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.742, total=369.1min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.730, total=528.2min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.688, total=480.0min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.704, total=1187.5min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.733, total=416.8min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.728, total=677.3min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.689, total=475.6min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.703, total=1200.6min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.740, total=546.0min
# Using TensorFlow backend.
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.737, total=354.7min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.746, total=682.5min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.706, total=704.2min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.706, total=908.4min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.746, total=701.1min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.686, total=466.9min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.705, total=1201.2min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.739, total=551.8min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.683, total=538.7min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.711, total=917.7min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.729, total=438.4min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.739, total=412.4min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.734, total=544.7min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.687, total=607.1min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.736, total=408.9min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.747, total=547.9min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.688, total=571.3min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.710, total=1012.8min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.736, total=517.2min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.727, total=684.6min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.708, total=701.1min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.738, total=389.7min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.736, total=535.5min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.727, total=687.8min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.706, total=933.4min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.739, total=412.7min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=300, score=0.740, total=586.3min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.729, total=844.5min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.703, total=958.0min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.698, total=920.3min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.729, total=882.2min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.705, total=1201.1min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.726, total=739.2min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.687, total=687.4min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.702, total=1172.4min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.703, total=761.6min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.695, total=1132.5min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.746, total=754.1min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=100, score=0.687, total=660.3min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.705, total=1188.0min
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.705, total=986.6min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.698, total=1056.5min
# Using TensorFlow backend.
# [Parallel(n_jobs=8)]: Done  90 out of  90 | elapsed: 8184.4min finished
# Using TensorFlow backend.
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=100, score=0.745, total=362.7min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.747, total=686.0min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.706, total=697.0min
# [CV] estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.01, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.695, total=913.2min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.747, total=706.5min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.705, total=713.9min
# [CV] estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=0.1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.705, total=1219.3min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=0, estimator__doc2vec__vector_size=500, score=0.746, total=808.8min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300, score=0.708, total=1006.6min
# [CV] estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500
# [CV]  estimator__clf__alpha=1, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500, score=0.696, total=1070.1min
# Best Parameters: {'estimator__clf__alpha': 1, 'estimator__doc2vec__dm': 0, 'estimator__doc2vec__vector_size': 300}
# Mean cross-validated F1-score of the best estimator: 0.7400013705108043

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('Normalizing', MinMaxScaler()),
    ('clf', MultinomialNB())
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__doc2vec__dm': [0],
    'estimator__doc2vec__vector_size': [300],
    'estimator__clf__alpha': [1] # Additive (Laplace/Lidstone) smoothing parameter (0 for no smoothing)
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=2, order=1) 
# Optimize for macro F1-score (same weight for each label)
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_nb = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_nb.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_nb.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_nb.best_score_))

# %%
evaluation(grid_nb, X_test, Y_test)

# %% [markdown]
# ### 5.3. XGBoost

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('clf', XGBClassifier())
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__doc2vec__dm': [0, 1],
    'estimator__doc2vec__vector_size': [100, 300, 500],
    'estimator__clf__n_estimators': [50, 100], # Number of boosting rounds
    'estimator__clf__max_depth': [5, 10] # Maximum tree depth for base learners
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=5, order=1) 
# Optimize for macro F1-score (same weight for each label)
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_xgb = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_xgb.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_xgb.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_xgb.best_score_))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ...
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [18:10:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:08:07] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:03:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:59:12] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:55:03] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:51:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:59:26] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:02:43] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5] END estimator__clf__max_depth=10, estimator__clf__n_estimators=100, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=300;, score=0.860 total time=849.4min
# [03:59:47] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [05:08:44] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [06:17:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:26:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:34:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:42:59] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:49:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:05:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:11:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:21:48] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:34:40] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:55:53] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5] END estimator__clf__max_depth=10, estimator__clf__n_estimators=100, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500;, score=0.850 total time=1031.3min
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/jbaumert/miniconda3/envs/ma-jonathan/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [05:04:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [06:13:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [07:22:13] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [08:29:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:36:51] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:44:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:00:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:12:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:29:14] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:41:18] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:01:53] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5] END estimator__clf__max_depth=10, estimator__clf__n_estimators=100, estimator__doc2vec__dm=1, estimator__doc2vec__vector_size=500;, score=0.840 total time=1039.1min
# [20:52:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:31:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [22:19:19] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:15:04] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:12:09] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:06:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:02:44] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [02:58:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:42:58] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:28:21] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [05:13:16] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [05:58:10] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [06:44:25] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best Parameters: {'estimator__clf__max_depth': 10, 'estimator__clf__n_estimators': 100, 'estimator__doc2vec__dm': 1, 'estimator__doc2vec__vector_size': 100}
# Mean cross-validated F1-score of the best estimator: 0.8624523778837224

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('clf', XGBClassifier())
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__doc2vec__dm': [1],
    'estimator__doc2vec__vector_size': [100],
    'estimator__clf__n_estimators': [100], # Number of boosting rounds
    'estimator__clf__max_depth': [10] # Maximum tree depth for base learners
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=2, order=1) 
# Optimize for macro F1-score (same weight for each label)
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_xgb = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_xgb.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_xgb.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_xgb.best_score_))

# %%
evaluation(grid_xgb, X_test, Y_test)

# %% [markdown]
# ## 6. Repeat classification performed in NLP for SDGs paper without masked organization names
# (No parameter tuning, use same parameters as before to obtain comparable restuls)

# %%
# Load data
df = pd.read_pickle("data/processed/reports_tokenized_unmasked.p")
df
# Out:
#          ID Identifier                Company_Name          ISIN Ticker  \
# 0         0      888.L            888 Holdings PLC  GI000A0F6407    888
# 1         1        A.N    Agilent Technologies Inc  US00846U1016      A
# ...     ...        ...                         ...           ...    ...
# 8101  12676      ZBH.N  Zimmer Biomet Holdings Inc  US98956P1021    ZBH
# 8102  12677      ZBH.N  Zimmer Biomet Holdings Inc  US98956P1021    ZBH
#
#            Country_of_Exchange  Financial_Period_Absolute  \
# 0               United Kingdom                       2020
# 1     United States of America                       2020
# ...                        ...                        ...
# 8101  United States of America                       2016
# 8102  United States of America                       2015
#
#      Financial_Period_Relative  \
# 0                          FY0
# 1                          FY0
# ...                        ...
# 8101                      FY-4
# 8102                      FY-5
#
#                                                                                                CSR_URL  \
# 0                          https://corporate.888.com/wp-content/uploads/2021/04/2020-Annual-Report.pdf
# 1                 https://www.agilent.com/about/companyinfo/sustainability/Agilent-Report-CSR-2020.pdf
# ...                                                                                                ...
# 8101  https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/z/NYSE_ZBH_2016.pdf
# 8102  https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/z/NYSE_ZBH_2015.pdf
#
#       SDG_1  SDG_2  SDG_3  SDG_4  SDG_5  SDG_6  SDG_7  SDG_8  SDG_9  SDG_10  \
# 0     False  False   True   True   True   True   True   True  False     NaN
# 1     False  False   True   True   True   True   True   True  False     NaN
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 8101  False  False   True   True   True   True   True   True  False     NaN
# 8102  False  False   True   True  False   True   True  False  False     NaN
#
#       SDG_11  SDG_12  SDG_13  SDG_14  SDG_15  SDG_16  SDG_17  \
# 0      False    True    True     NaN   False    True   False
# 1      False    True    True     NaN    True    True   False
# ...      ...     ...     ...     ...     ...     ...     ...
# 8101   False    True   False     NaN   False    True   False
# 8102   False    True   False     NaN   False   False   False
#
#               CSR_Filename  \
# 0         0_888.L_2020.pdf
# 1           1_A.N_2020.pdf
# ...                    ...
# 8101  12676_ZBH.N_2016.pdf
# 8102  12677_ZBH.N_2015.pdf
#
#                                                                                            CSR_Text_clean  \
# 0     888 HOLDINGS PLC ANNUAL REPORT & ACCOUNTS 2020 A YEAR OF STRONG GROWTH 888 IS ONE OF THE WORLDS ...
# 1     Delivering on our Promises 2020 Corporate Social Responsibility Report 1 Letter from the Preside...
# ...                                                                                                   ...
# 8101  E N V I R O N M E N T A L S O C I A L G O V E R N A N C E Sustainability Report 2016 T A B L E O...
# 8102  E N V I R O N M E N T A L S O C I A L G O V E R N A N C E Sustainability Report 2015 Investing n...
#
#                                                                                        CSR_Text_tokenized
# 0     holding plc annual report account year strong growth one world leading online betting gaming com...
# 1     delivering promise corporate social responsibility report letter president stakeholder engagemen...
# ...                                                                                                   ...
# 8101  sustainability report company profile corporate overview purpose mission value sustainability co...
# 8102  sustainability report investing future world letter ceo stakeholder company profile corporate ov...
#
# [8103 rows x 29 columns]

# %%
# Transform labels to numpy array: Exclude SDGs 2 and 9 (too few aligned examples) and 10 and 14 (no mapping) -> 13 labels left
labels = [
    "SDG_1",
    "SDG_3",
    "SDG_4",
    "SDG_5",
    "SDG_6",
    "SDG_7",
    "SDG_8",
    "SDG_11",
    "SDG_12",
    "SDG_13",
    "SDG_15",
    "SDG_16",
    "SDG_17",
]
Y = df[labels].to_numpy().astype(int)

# %%
# Split into 80% training and 20% test data (stratified for multi-label, adapted to work with df column)

np.random.seed(7)

X_train, Y_train, X_test, Y_test = iterative_train_test_split(df['CSR_Text_tokenized'], Y, test_size=0.2)

# %%
np.random.seed(7)

# Pipeline: Resample data with smote and afterwards pass output to classifier
pipeline = Pipeline([
    ('doc2vec', Doc2VecModel(dm=0, vector_size=100, window=5, epochs=30)), 
    ('smote', SMOTE()), 
    ('clf', SVC(kernel='linear'))
])

# Transform Y into single labels and pass single label data to different copies of pipeline
ovr = OneVsRestClassifier(pipeline)

# Parameter to test in Grid Search
parameters = {
    'estimator__clf__C': [10] # Inverse of regularization strength, smaller values specify stronger regularization
}

# Use stratified sampling in each iteration
stratified_k_fold_cv = IterativeStratification(n_splits=2, order=1) 
# Optimize for macro F1-score
scorer = make_scorer(f1_score, average = 'macro')

# Grid Search
grid_svm_paper_unmasked = GridSearchCV(ovr, parameters, cv=stratified_k_fold_cv, scoring=scorer, n_jobs=8, verbose=3)
grid_svm_paper_unmasked.fit(X_train, Y_train)

# Print results
print("Best Parameters: {}".format(grid_svm_paper_unmasked.best_params_))
print("Mean cross-validated F1-score of the best estimator: {}".format(grid_svm_paper_unmasked.best_score_))
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [CV 1/2] END .............estimator__clf__C=10;, score=0.746 total time=376.7min
# [CV 2/2] END .............estimator__clf__C=10;, score=0.753 total time=377.3min
# Best Parameters: {'estimator__clf__C': 10}
# Mean cross-validated F1-score of the best estimator: 0.7494629358689469

# %%
evaluation(grid_svm_paper_unmasked, X_test, Y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.74      0.53       205
#            1       0.93      0.68      0.79      1483
#            2       0.87      0.59      0.70      1435
#            3       0.89      0.69      0.78      1311
#            4       0.92      0.62      0.74      1411
#            5       0.90      0.62      0.73      1309
#            6       0.86      0.76      0.81      1227
#            7       0.36      0.76      0.49       199
#            8       0.95      0.61      0.74      1528
#            9       0.83      0.55      0.66      1144
#           10       0.63      0.71      0.67       582
#           11       0.86      0.68      0.76      1251
#           12       0.39      0.78      0.52       199
#
#    micro avg       0.82      0.65      0.73     13284
#    macro avg       0.75      0.68      0.69     13284
# weighted avg       0.86      0.65      0.73     13284
#  samples avg       0.75      0.61      0.64     13284
