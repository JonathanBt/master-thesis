# %%
import os

os.chdir("..")

# %%
# Select GPUs to use
os.environ['CUDA_DEVICE_ORDER']='PCI_BUS_ID'
#os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3,4,5,6,7'
os.environ['CUDA_VISIBLE_DEVICES'] = '0,2,3,6'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings("ignore")
import random
import time
import datetime

# Evaluation
from sklearn.metrics import (
    f1_score,
    classification_report,
    confusion_matrix
)

# Transformers
import torch
from torch.nn import BCEWithLogitsLoss, DataParallel
from torch.utils.data import TensorDataset, DataLoader
from torch.optim import RAdam
from transformers import LongformerTokenizerFast, LongformerForSequenceClassification, AdamW
from transformers import get_linear_schedule_with_warmup 

from src.models.evaluation import evaluation
from src.data.iterative_train_test_split import iterative_train_test_split

# %%
pd.set_option("display.max_rows", 5)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

# %%
# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(hash("setting random seeds") % 2**32 - 1)
np.random.seed(hash("improves reproducibility") % 2**32 - 1)
torch.manual_seed(hash("by removing stochasticity") % 2**32 - 1)
torch.cuda.manual_seed_all(hash("so runs are repeatable") % 2**32 - 1)

# %%
# Use GPU
torch.cuda.empty_cache()
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 1. Load and transform data

# %%
# Load data
df = pd.read_pickle("data/processed/reports_tokenized.p")
df
# Out:
#         ID Identifier                Company_Name          ISIN Ticker  \
# 0        0      888.L            888 Holdings PLC  GI000A0F6407    888
# 1        1        A.N    Agilent Technologies Inc  US00846U1016      A
# ...    ...        ...                         ...           ...    ...
# 8101  8101      ZBH.N  Zimmer Biomet Holdings Inc  US98956P1021    ZBH
# 8102  8102      ZBH.N  Zimmer Biomet Holdings Inc  US98956P1021    ZBH
#
#            Country_of_Exchange  Financial_Period_Absolute  \
# 0               United Kingdom                       2020
# 1     United States of America                       2020
# ...                        ...                        ...
# 8101  United States of America                       2016
# 8102  United States of America                       2015
#
#      Financial_Period_Relative  \
# 0                          FY0
# 1                          FY0
# ...                        ...
# 8101                      FY-4
# 8102                      FY-5
#
#                                                                                                CSR_URL  \
# 0                          https://corporate.888.com/wp-content/uploads/2021/04/2020-Annual-Report.pdf
# 1                 https://www.agilent.com/about/companyinfo/sustainability/Agilent-Report-CSR-2020.pdf
# ...                                                                                                ...
# 8101  https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/z/NYSE_ZBH_2016.pdf
# 8102  https://www.responsibilityreports.com/HostedData/ResponsibilityReportArchive/z/NYSE_ZBH_2015.pdf
#
#       SDG_1  SDG_2  SDG_3  SDG_4  SDG_5  SDG_6  SDG_7  SDG_8  SDG_9  SDG_10  \
# 0     False  False   True   True   True   True   True   True  False     NaN
# 1     False  False   True   True   True   True   True   True  False     NaN
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 8101  False  False   True   True   True   True   True   True  False     NaN
# 8102  False  False   True   True  False   True   True  False  False     NaN
#
#       SDG_11  SDG_12  SDG_13  SDG_14  SDG_15  SDG_16  SDG_17  \
# 0      False    True    True     NaN   False    True   False
# 1      False    True    True     NaN    True    True   False
# ...      ...     ...     ...     ...     ...     ...     ...
# 8101   False    True   False     NaN   False    True   False
# 8102   False    True   False     NaN   False   False   False
#
#               CSR_Filename  \
# 0         0_888.L_2020.pdf
# 1           1_A.N_2020.pdf
# ...                    ...
# 8101  12676_ZBH.N_2016.pdf
# 8102  12677_ZBH.N_2015.pdf
#
#                                                                                                  CSR_Text  \
# 0     888 HOLDINGS PLC\n\nANNUAL REPORT & ACCOUNTS 2020\n\n
# A YEAR OF  \nSTRONG GROWTH \n\n888 IS ONE ...
# 1     Delivering on  \nour Promises\n\n2020 Corporate Social Responsibility Report\n\n1\n\n
# Letter fro...
# ...                                                                                                   ...
# 8101  E N V I R O N M E N T A L  \n\n \n\nS O C I A L  \n\nG O V E R N A N C E\n\nSustainability \nRep...
# 8102  E N V I R O N M E N T A L  \n\n \n\nS O C I A L  \n\nG O V E R N A N C E\n\nSustainability \nRep...
#
#                                                                                            CSR_Text_clean  \
# 0     888 ORG ANNUAL REPORT & ACCOUNTS 2020 A YEAR OF STRONG GROWTH ORG IS ONE OF THE WORLDS LEADING O...
# 1     Delivering on our Promises 2020 Corporate ORG 1 Letter from the President Stakeholder engagement...
# ...                                                                                                   ...
# 8101  E N V I R O N M E N T A L S O C I A L G O V E R N A N C E Sustainability Report 2016 T A B L E O...
# 8102  E N V I R O N M E N T A L S O C I A L G O V E R N A N C E Sustainability Report 2015 Investing n...
#
#                                                                                        CSR_Text_tokenized
# 0     org annual report account year strong growth org one world leading online betting gaming company...
# 1     delivering promise corporate org letter president stakeholder engagement environment table conte...
# ...                                                                                                   ...
# 8101  sustainability report company profile corporate overview purpose mission value sustainability co...
# 8102  sustainability report investing future world letter ceo stakeholder company profile corporate ov...
#
# [8103 rows x 30 columns]

# %%
# Transform labels to numpy array: Exclude SDGs 2 and 9 (too few aligned examples) and 10 and 14 (no mapping) -> 13 labels left
labels = [
    "SDG_1",
    "SDG_3",
    "SDG_4",
    "SDG_5",
    "SDG_6",
    "SDG_7",
    "SDG_8",
    "SDG_11",
    "SDG_12",
    "SDG_13",
    "SDG_15",
    "SDG_16",
    "SDG_17",
]
Y = df[labels].to_numpy().astype(int)

# %%
# Split into 70% training, 15% validation, and 15% test data (stratified for multi-label, adapted to work with df column)

np.random.seed(7)

X_train, Y_train, X_test, Y_test = iterative_train_test_split(df['CSR_Text_clean'], Y, test_size=0.3)
X_val, Y_val, X_test, Y_test = iterative_train_test_split(X_test, Y_test, test_size=0.5)

# %%
# Load tokenizer
tokenizer = LongformerTokenizerFast.from_pretrained("allenai/longformer-base-4096")

# %%
# Function to split a CSR and its corresponding label into encoding chunks of 4096 tokens

def split_doc_into_encoding_chunks_with_labels(doc, label):

    # Initialize lists to store encodings
    input_ids_list = []
    attention_mask_list = []
    label_list = []

    # Tokenize document without adding cls and sep token
    encoding = tokenizer(doc, add_special_tokens=False)
    input_ids = encoding['input_ids']
    attention_mask = encoding['attention_mask']

    # Split encoding into chunks of 4096

    start = 0 # Starting position for chunking
    window_size = 4094  # we take 2 off here so that we can fit in our [s] and [SEP] tokens
    total_len = len(input_ids)

    loop = True
    while loop:
        # End position = start + window_size
        end = start + window_size
        # If end position is greater than total length, stop and change endpoint to the final token position
        if end >= total_len:
            loop = False
            end = total_len
        # (1) Extract window from input_ids and attention_mask
        input_ids_chunk = input_ids[start:end]
        attention_mask_chunk = attention_mask[start:end]
        # (2) Add [s] and [SEP] tokens (0 and 2 in Longformer)
        input_ids_chunk = [0] + input_ids_chunk + [2]
        attention_mask_chunk = [1] + attention_mask_chunk + [1]
        # (3) Add padding up to window_size + 2 tokens
        input_ids_chunk += [0] * (window_size - len(input_ids_chunk) + 2)
        attention_mask_chunk += [0] * (window_size - len(attention_mask_chunk) + 2)
        # (4) Format into PyTorch tensors
        input_ids_list.append(input_ids_chunk)
        attention_mask_list.append(attention_mask_chunk)
        # (5) Store label
        label_list.append(label)
        # Move the window to the next 4096 tokens
        start = end

    # Create dictionary from lists
    encoding_dict = {
        'input_ids': torch.Tensor(input_ids_list).long(),
        'attention_mask': torch.Tensor(attention_mask_list).long(),
        'label': torch.Tensor(label_list).float()
    }

    return encoding_dict

# %%
# Function to create a dict for the training/ validation set

def create_encoding_label_dict(X, Y):
    
    X = list(X)

    i = 0
    # Iterate through CSRs
    for i in tqdm(range(len(X))):
        # Encode doc
        encoding_dict = split_doc_into_encoding_chunks_with_labels(X[i], Y[i])
        if i == 0:
            # Initialize dict
            encoding_dict_full = encoding_dict
        else:
            # Append dict
            encoding_dict_full['input_ids'] = torch.cat([encoding_dict_full['input_ids'], encoding_dict['input_ids']])
            encoding_dict_full['attention_mask'] = torch.cat([encoding_dict_full['attention_mask'], encoding_dict['attention_mask']])
            encoding_dict_full['label'] = torch.cat([encoding_dict_full['label'], encoding_dict['label']])
        i += 1
    
    return encoding_dict_full

# %%
# Encode data
train_encodings = create_encoding_label_dict(X_train, Y_train)
val_encodings = create_encoding_label_dict(X_val, Y_val)
# Out:
#   0%|          | 0/5485 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (38079 > 4096). Running this sequence through the model will result in indexing errors
#   0%|          | 0/1310 [00:00<?, ?it/s]

# %%
# Convert data into TensorDatasets
train_dataset = TensorDataset(train_encodings['input_ids'], train_encodings['attention_mask'], train_encodings['label'])
val_dataset = TensorDataset(val_encodings['input_ids'], val_encodings['attention_mask'], val_encodings['label'])

# %%
# Create the DataLoader

batch_size = 8
    
train_dataloader = DataLoader(train_dataset, batch_size, shuffle = True)
val_dataloader = DataLoader(val_dataset, batch_size, shuffle = True)

# %% [markdown]
# ## 2. Load model

# %%
# Load model
model = LongformerForSequenceClassification.from_pretrained("allenai/longformer-base-4096", problem_type="multi_label_classification", num_labels=13)
model = DataParallel(model)
model.to(device)
# Out:
# Some weights of the model checkpoint at allenai/longformer-base-4096 were not used when initializing LongformerForSequenceClassification: ['lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing LongformerForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DataParallel(
#   (module): LongformerForSequenceClassification(
#     (longformer): LongformerModel(
#       (embeddings): LongformerEmbeddings(
#         (word_embeddings): Embedding(50265, 768, padding_idx=1)
#         (position_embeddings): Embedding(4098, 768, padding_idx=1)
#         (token_type_embeddings): Embedding(1, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): LongformerEncoder(
#         (layer): ModuleList(
#           (0): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): LongformerLayer(
#             (attention): LongformerAttention(
#               (self): LongformerSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (query_global): Linear(in_features=768, out_features=768, bias=True)
#                 (key_global): Linear(in_features=768, out_features=768, bias=True)
#                 (value_global): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (output): LongformerSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): LongformerIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): LongformerOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (classifier): LongformerClassificationHead(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (out_proj): Linear(in_features=768, out_features=13, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## 3. Train

# %%
# Define helper functions

# Function to calculate the weights for the positive class
def calculate_pos_weights(labels):
    pos_counts = labels.sum(axis=0)
    neg_counts = len(labels) - pos_counts
    pos_weights = neg_counts / (pos_counts + 1e-5)
    return torch.as_tensor(pos_weights, dtype=torch.float)

# Function to format a time in seconds into a string hh:mm:ss
def format_time(elapsed):
    elapsed_rounded = int(round((elapsed)))
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
# Prepare training

# Parameters
epochs = 5
learning_rate = 2e-5 #5e-6
warumup_steps = 0

# Optimizer
optimizer = RAdam(model.parameters(), lr=learning_rate)

# Total number of training steps is [number of batches] x [number of epochs].
total_steps = len(train_dataloader) * epochs

# Create the learning rate scheduler (linear decreasing lr without warmup)
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = warumup_steps, 
                                            num_training_steps = total_steps)

# Calculate the weights for the positive class for the training data
pos_weight = calculate_pos_weights(Y_train)

# Training with BCEWithLogitsLoss instead of CrossEntropyLoss()
loss_fct_train = BCEWithLogitsLoss(pos_weight=pos_weight.to(device))
loss_fct_val = BCEWithLogitsLoss()

# %%
# Training

# Store training and validation loss, validation F1 score, and timings
training_stats = []

# Measure the total training time for the whole run
total_t0 = time.time()

# For each epoch...
for epoch_i in range(0, epochs):
    
    # ========================================
    #               Training
    # ========================================

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    t0 = time.time()
    total_train_loss = 0

    model.train()

    for step, batch in enumerate(train_dataloader):

        # Print progress update 
        if step % 100 == 0 and not step == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack the batch from the dataloader and copy each tensor to the GPU
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        # Always clear any previously calculated gradients before performing a backward pass
        model.zero_grad()        

        # Perform a forward pass (evaluate the model on this training batch) and return the loss (because we provided labels) and the logits
        result = model(b_input_ids, 
                       token_type_ids=None, 
                       attention_mask=b_input_mask, 
                       labels=b_labels,
                       return_dict=True)

        logits = result.logits
        loss = loss_fct_train(logits, b_labels)

        # Accumulate the training loss over all of the batches so that we can calculate the average loss at the end
        total_train_loss += loss.item()

        # Perform a backward pass to calculate the gradients
        loss.backward()

        # Clip the norm of the gradients to 1.0. to help prevent the "exploding gradients" problem
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient
        optimizer.step()

        # Update the learning rate
        scheduler.step()

    # Calculate the average loss over all of the batches
    avg_train_loss = total_train_loss / len(train_dataloader)            
    
    # Measure how long this epoch took
    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epoch took: {:}".format(training_time))
        
    # ========================================
    #               Validation
    # ========================================

    print("")
    print("Running Validation...")

    t0 = time.time()

    model.eval()
    
    predictions , true_labels = [], []

    total_eval_f1 = 0
    total_eval_loss = 0
    nb_eval_steps = 0

    for batch in val_dataloader:
        
        # Unpack the batch from the dataloader and copy each tensor to the GPU
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        
        # Tell pytorch not to bother with constructing the compute graph during the forward pass, since this is only needed for backprop (training)
        with torch.no_grad():        

            # Forward pass, calculate logit predictions
            result = model(b_input_ids, 
                           token_type_ids=None, 
                           attention_mask=b_input_mask,
                           labels=b_labels,
                           return_dict=True)

        # Get the loss and "logits" output by the model
        logits = result.logits
        loss = loss_fct_val(logits, b_labels)
            
        # Accumulate the validation loss
        total_eval_loss += loss.item()

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        # Store predictions and true labels
        predictions.append(logits)
        true_labels.append(label_ids)
        
    # Report the final macro F1 score for this validation run
    predicted_labels = torch.round(torch.sigmoid(torch.Tensor(np.concatenate(predictions, axis=0)))).numpy().astype(int)
    true_labels = np.concatenate(true_labels, axis=0).astype(int)
    avg_val_f1 = f1_score(predicted_labels, true_labels, average='macro')
    print("  Macro F1 score: {0:.2f}".format(avg_val_f1))    
    
    # Calculate the average loss over all of the batches
    avg_val_loss = total_eval_loss / len(val_dataloader)
    
    # Measure how long the validation run took
    validation_time = format_time(time.time() - t0)
    
    print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    print("  Validation took: {:}".format(validation_time))

    # Record all statistics from this epoch
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Macro F1 score.': avg_val_f1,
            'Training Time': training_time,
            'Validation Time': validation_time
        }
    )
    
    # Save model
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, 'models/longformer_full_text_epoch_' + str(epoch_i + 1) + '.pt')

print("")
print("Training complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 5 ========
# Training...
#   Batch   100  of  5,992.    Elapsed: 0:04:35.
#   Batch   200  of  5,992.    Elapsed: 0:08:59.
#   Batch   300  of  5,992.    Elapsed: 0:13:27.
#   Batch   400  of  5,992.    Elapsed: 0:17:58.
#   Batch   500  of  5,992.    Elapsed: 0:22:30.
#   Batch   600  of  5,992.    Elapsed: 0:27:02.
#   Batch   700  of  5,992.    Elapsed: 0:31:32.
#   Batch   800  of  5,992.    Elapsed: 0:36:05.
#   Batch   900  of  5,992.    Elapsed: 0:40:35.
#   Batch 1,000  of  5,992.    Elapsed: 0:45:01.
#   Batch 1,100  of  5,992.    Elapsed: 0:49:29.
#   Batch 1,200  of  5,992.    Elapsed: 0:54:00.
#   Batch 1,300  of  5,992.    Elapsed: 0:58:31.
#   Batch 1,400  of  5,992.    Elapsed: 1:03:01.
#   Batch 1,500  of  5,992.    Elapsed: 1:07:30.
#   Batch 1,600  of  5,992.    Elapsed: 1:12:00.
#   Batch 1,700  of  5,992.    Elapsed: 1:16:24.
#   Batch 1,800  of  5,992.    Elapsed: 1:20:51.
#   Batch 1,900  of  5,992.    Elapsed: 1:25:19.
#   Batch 2,000  of  5,992.    Elapsed: 1:29:48.
#   Batch 2,100  of  5,992.    Elapsed: 1:34:17.
#   Batch 2,200  of  5,992.    Elapsed: 1:38:49.
#   Batch 2,300  of  5,992.    Elapsed: 1:43:23.
#   Batch 2,400  of  5,992.    Elapsed: 1:47:57.
#   Batch 2,500  of  5,992.    Elapsed: 1:52:26.
#   Batch 2,600  of  5,992.    Elapsed: 1:56:53.
#   Batch 2,700  of  5,992.    Elapsed: 2:01:23.
#   Batch 2,800  of  5,992.    Elapsed: 2:05:55.
#   Batch 2,900  of  5,992.    Elapsed: 2:10:20.
#   Batch 3,000  of  5,992.    Elapsed: 2:14:50.
#   Batch 3,100  of  5,992.    Elapsed: 2:19:20.
#   Batch 3,200  of  5,992.    Elapsed: 2:23:49.
#   Batch 3,300  of  5,992.    Elapsed: 2:28:18.
#   Batch 3,400  of  5,992.    Elapsed: 2:32:56.
#   Batch 3,500  of  5,992.    Elapsed: 2:37:37.
#   Batch 3,600  of  5,992.    Elapsed: 2:42:20.
#   Batch 3,700  of  5,992.    Elapsed: 2:47:02.
#   Batch 3,800  of  5,992.    Elapsed: 2:52:17.
#   Batch 3,900  of  5,992.    Elapsed: 2:59:29.
#   Batch 4,000  of  5,992.    Elapsed: 3:06:27.
#   Batch 4,100  of  5,992.    Elapsed: 3:13:39.
#   Batch 4,200  of  5,992.    Elapsed: 3:20:46.
#   Batch 4,300  of  5,992.    Elapsed: 3:28:00.
#   Batch 4,400  of  5,992.    Elapsed: 3:35:13.
#   Batch 4,500  of  5,992.    Elapsed: 3:42:33.
#   Batch 4,600  of  5,992.    Elapsed: 3:49:51.
#   Batch 4,700  of  5,992.    Elapsed: 3:57:16.
#   Batch 4,800  of  5,992.    Elapsed: 4:04:33.
#   Batch 4,900  of  5,992.    Elapsed: 4:11:38.
#   Batch 5,000  of  5,992.    Elapsed: 4:18:44.
#   Batch 5,100  of  5,992.    Elapsed: 4:25:44.
#   Batch 5,200  of  5,992.    Elapsed: 4:32:49.
#   Batch 5,300  of  5,992.    Elapsed: 4:40:04.
#   Batch 5,400  of  5,992.    Elapsed: 4:47:16.
#   Batch 5,500  of  5,992.    Elapsed: 4:54:38.
#   Batch 5,600  of  5,992.    Elapsed: 5:02:02.
#   Batch 5,700  of  5,992.    Elapsed: 5:09:27.
#   Batch 5,800  of  5,992.    Elapsed: 5:16:53.
#   Batch 5,900  of  5,992.    Elapsed: 5:24:13.
#
#   Average training loss: 0.39
#   Training epoch took: 5:31:06
#
# Running Validation...
#   Macro F1 score: 0.73
#   Validation Loss: 0.52
#   Validation took: 0:35:36
#
# ======== Epoch 2 / 5 ========
# Training...
#   Batch   100  of  5,992.    Elapsed: 0:04:58.
#   Batch   200  of  5,992.    Elapsed: 0:09:52.
#   Batch   300  of  5,992.    Elapsed: 0:14:45.
#   Batch   400  of  5,992.    Elapsed: 0:19:39.
#   Batch   500  of  5,992.    Elapsed: 0:24:32.
#   Batch   600  of  5,992.    Elapsed: 0:29:28.
#   Batch   700  of  5,992.    Elapsed: 0:34:23.
#   Batch   800  of  5,992.    Elapsed: 0:39:22.
#   Batch   900  of  5,992.    Elapsed: 0:44:22.
#   Batch 1,000  of  5,992.    Elapsed: 0:49:21.
#   Batch 1,100  of  5,992.    Elapsed: 0:54:16.
#   Batch 1,200  of  5,992.    Elapsed: 0:59:15.
#   Batch 1,300  of  5,992.    Elapsed: 1:04:12.
#   Batch 1,400  of  5,992.    Elapsed: 1:09:12.
#   Batch 1,500  of  5,992.    Elapsed: 1:14:11.
#   Batch 1,600  of  5,992.    Elapsed: 1:19:12.
#   Batch 1,700  of  5,992.    Elapsed: 1:24:12.
#   Batch 1,800  of  5,992.    Elapsed: 1:29:12.
#   Batch 1,900  of  5,992.    Elapsed: 1:34:12.
#   Batch 2,000  of  5,992.    Elapsed: 1:39:11.
#   Batch 2,100  of  5,992.    Elapsed: 1:44:11.
#   Batch 2,200  of  5,992.    Elapsed: 1:49:10.
#   Batch 2,300  of  5,992.    Elapsed: 1:54:09.
#   Batch 2,400  of  5,992.    Elapsed: 1:59:09.
#   Batch 2,500  of  5,992.    Elapsed: 2:04:08.
#   Batch 2,600  of  5,992.    Elapsed: 2:09:06.
#   Batch 2,700  of  5,992.    Elapsed: 2:14:05.
#   Batch 2,800  of  5,992.    Elapsed: 2:19:04.
#   Batch 2,900  of  5,992.    Elapsed: 2:24:03.
#   Batch 3,000  of  5,992.    Elapsed: 2:29:03.
#   Batch 3,100  of  5,992.    Elapsed: 2:34:03.
#   Batch 3,200  of  5,992.    Elapsed: 2:39:03.
#   Batch 3,300  of  5,992.    Elapsed: 2:43:59.
#   Batch 3,400  of  5,992.    Elapsed: 2:48:56.
#   Batch 3,500  of  5,992.    Elapsed: 2:53:58.
#   Batch 3,600  of  5,992.    Elapsed: 2:59:03.
#   Batch 3,700  of  5,992.    Elapsed: 3:04:07.
#   Batch 3,800  of  5,992.    Elapsed: 3:09:12.
#   Batch 3,900  of  5,992.    Elapsed: 3:14:15.
#   Batch 4,000  of  5,992.    Elapsed: 3:19:18.
#   Batch 4,100  of  5,992.    Elapsed: 3:24:21.
#   Batch 4,200  of  5,992.    Elapsed: 3:29:24.
#   Batch 4,300  of  5,992.    Elapsed: 3:34:28.
#   Batch 4,400  of  5,992.    Elapsed: 3:39:32.
#   Batch 4,500  of  5,992.    Elapsed: 3:44:35.
#   Batch 4,600  of  5,992.    Elapsed: 3:49:37.
#   Batch 4,700  of  5,992.    Elapsed: 3:54:40.
#   Batch 4,800  of  5,992.    Elapsed: 3:59:43.
#   Batch 4,900  of  5,992.    Elapsed: 4:04:45.
#   Batch 5,000  of  5,992.    Elapsed: 4:09:46.
#   Batch 5,100  of  5,992.    Elapsed: 4:14:47.
#   Batch 5,200  of  5,992.    Elapsed: 4:19:48.
#   Batch 5,300  of  5,992.    Elapsed: 4:24:50.
#   Batch 5,400  of  5,992.    Elapsed: 4:31:11.
#   Batch 5,500  of  5,992.    Elapsed: 4:38:41.
#   Batch 5,600  of  5,992.    Elapsed: 4:46:05.
#   Batch 5,700  of  5,992.    Elapsed: 4:53:36.
#   Batch 5,800  of  5,992.    Elapsed: 5:00:59.
#   Batch 5,900  of  5,992.    Elapsed: 5:08:29.
#
#   Average training loss: 0.22
#   Training epoch took: 5:15:16
#
# Running Validation...
#   Macro F1 score: 0.79
#   Validation Loss: 0.48
#   Validation took: 0:39:29
#
# ======== Epoch 3 / 5 ========
# Training...
#   Batch   100  of  5,992.    Elapsed: 0:06:59.
#   Batch   200  of  5,992.    Elapsed: 0:14:07.
#   Batch   300  of  5,992.    Elapsed: 0:21:06.
#   Batch   400  of  5,992.    Elapsed: 0:28:15.
#   Batch   500  of  5,992.    Elapsed: 0:35:13.
#   Batch   600  of  5,992.    Elapsed: 0:42:17.
#   Batch   700  of  5,992.    Elapsed: 0:49:14.
#   Batch   800  of  5,992.    Elapsed: 0:56:21.
#   Batch   900  of  5,992.    Elapsed: 1:03:20.
#   Batch 1,000  of  5,992.    Elapsed: 1:10:05.
#   Batch 1,100  of  5,992.    Elapsed: 1:15:12.
#   Batch 1,200  of  5,992.    Elapsed: 1:19:59.
#   Batch 1,300  of  5,992.    Elapsed: 1:25:36.
#   Batch 1,400  of  5,992.    Elapsed: 1:32:29.
#   Batch 1,500  of  5,992.    Elapsed: 1:39:18.
#   Batch 1,600  of  5,992.    Elapsed: 1:46:18.
#   Batch 1,700  of  5,992.    Elapsed: 1:53:28.
#   Batch 1,800  of  5,992.    Elapsed: 2:00:38.
#   Batch 1,900  of  5,992.    Elapsed: 2:07:56.
#   Batch 2,000  of  5,992.    Elapsed: 2:15:17.
#   Batch 2,100  of  5,992.    Elapsed: 2:22:32.
#   Batch 2,200  of  5,992.    Elapsed: 2:29:33.
#   Batch 2,300  of  5,992.    Elapsed: 2:36:28.
#   Batch 2,400  of  5,992.    Elapsed: 2:44:01.
#   Batch 2,500  of  5,992.    Elapsed: 2:51:32.
#   Batch 2,600  of  5,992.    Elapsed: 2:58:44.
#   Batch 2,700  of  5,992.    Elapsed: 3:06:05.
#   Batch 2,800  of  5,992.    Elapsed: 3:13:33.
#   Batch 2,900  of  5,992.    Elapsed: 3:20:54.
#   Batch 3,000  of  5,992.    Elapsed: 3:27:54.
#   Batch 3,100  of  5,992.    Elapsed: 3:35:06.
#   Batch 3,200  of  5,992.    Elapsed: 3:42:27.
#   Batch 3,300  of  5,992.    Elapsed: 3:49:56.
#   Batch 3,400  of  5,992.    Elapsed: 3:57:12.
#   Batch 3,500  of  5,992.    Elapsed: 4:04:28.
#   Batch 3,600  of  5,992.    Elapsed: 4:11:58.
#   Batch 3,700  of  5,992.    Elapsed: 4:19:07.
#   Batch 3,800  of  5,992.    Elapsed: 4:26:14.
#   Batch 3,900  of  5,992.    Elapsed: 4:33:27.
#   Batch 4,000  of  5,992.    Elapsed: 4:40:45.
#   Batch 4,100  of  5,992.    Elapsed: 4:48:16.
#   Batch 4,200  of  5,992.    Elapsed: 4:55:47.
#   Batch 4,300  of  5,992.    Elapsed: 5:03:10.
#   Batch 4,400  of  5,992.    Elapsed: 5:10:12.
#   Batch 4,500  of  5,992.    Elapsed: 5:17:12.
#   Batch 4,600  of  5,992.    Elapsed: 5:24:27.
#   Batch 4,700  of  5,992.    Elapsed: 5:31:51.
#   Batch 4,800  of  5,992.    Elapsed: 5:39:00.
#   Batch 4,900  of  5,992.    Elapsed: 5:46:09.
#   Batch 5,000  of  5,992.    Elapsed: 5:53:04.
#   Batch 5,100  of  5,992.    Elapsed: 6:00:06.
#   Batch 5,200  of  5,992.    Elapsed: 6:07:25.
#   Batch 5,300  of  5,992.    Elapsed: 6:14:33.
#   Batch 5,400  of  5,992.    Elapsed: 6:21:26.
#   Batch 5,500  of  5,992.    Elapsed: 6:28:17.
#   Batch 5,600  of  5,992.    Elapsed: 6:35:16.
#   Batch 5,700  of  5,992.    Elapsed: 6:42:15.
#   Batch 5,800  of  5,992.    Elapsed: 6:49:19.
#   Batch 5,900  of  5,992.    Elapsed: 6:56:38.
#
#   Average training loss: 0.14
#   Training epoch took: 7:03:56
#
# Running Validation...
#   Macro F1 score: 0.80
#   Validation Loss: 0.49
#   Validation took: 0:48:15
#
# ======== Epoch 4 / 5 ========
# Training...
#   Batch   100  of  5,992.    Elapsed: 0:07:03.
#   Batch   200  of  5,992.    Elapsed: 0:13:53.
#   Batch   300  of  5,992.    Elapsed: 0:21:53.
#   Batch   400  of  5,992.    Elapsed: 0:30:14.
#   Batch   500  of  5,992.    Elapsed: 0:37:07.
#   Batch   600  of  5,992.    Elapsed: 0:45:53.
#   Batch   700  of  5,992.    Elapsed: 0:52:28.
#   Batch   800  of  5,992.    Elapsed: 1:00:15.
#   Batch   900  of  5,992.    Elapsed: 1:08:17.
#   Batch 1,000  of  5,992.    Elapsed: 1:14:49.
#   Batch 1,100  of  5,992.    Elapsed: 1:21:53.
#   Batch 1,200  of  5,992.    Elapsed: 1:31:01.
#   Batch 1,300  of  5,992.    Elapsed: 1:37:46.
#   Batch 1,400  of  5,992.    Elapsed: 1:44:13.
#   Batch 1,500  of  5,992.    Elapsed: 1:50:49.
#   Batch 1,600  of  5,992.    Elapsed: 1:57:52.
#   Batch 1,700  of  5,992.    Elapsed: 2:04:02.
#   Batch 1,800  of  5,992.    Elapsed: 2:09:25.
#   Batch 1,900  of  5,992.    Elapsed: 2:16:17.
#   Batch 2,000  of  5,992.    Elapsed: 2:23:07.
#   Batch 2,100  of  5,992.    Elapsed: 2:29:55.
#   Batch 2,200  of  5,992.    Elapsed: 2:36:43.
#   Batch 2,300  of  5,992.    Elapsed: 2:43:37.
#   Batch 2,400  of  5,992.    Elapsed: 2:50:29.
#   Batch 2,500  of  5,992.    Elapsed: 2:57:25.
#   Batch 2,600  of  5,992.    Elapsed: 3:04:17.
#   Batch 2,700  of  5,992.    Elapsed: 3:11:02.
#   Batch 2,800  of  5,992.    Elapsed: 3:17:51.
#   Batch 2,900  of  5,992.    Elapsed: 3:24:34.
#   Batch 3,000  of  5,992.    Elapsed: 3:31:21.
#   Batch 3,100  of  5,992.    Elapsed: 3:38:15.
#   Batch 3,200  of  5,992.    Elapsed: 3:45:00.
#   Batch 3,300  of  5,992.    Elapsed: 3:51:46.
#   Batch 3,400  of  5,992.    Elapsed: 3:58:31.
#   Batch 3,500  of  5,992.    Elapsed: 4:05:17.
#   Batch 3,600  of  5,992.    Elapsed: 4:12:07.
#   Batch 3,700  of  5,992.    Elapsed: 4:19:04.
#   Batch 3,800  of  5,992.    Elapsed: 4:25:53.
#   Batch 3,900  of  5,992.    Elapsed: 4:32:44.
#   Batch 4,000  of  5,992.    Elapsed: 4:39:40.
#   Batch 4,100  of  5,992.    Elapsed: 4:46:37.
#   Batch 4,200  of  5,992.    Elapsed: 4:53:31.
#   Batch 4,300  of  5,992.    Elapsed: 5:00:22.
#   Batch 4,400  of  5,992.    Elapsed: 5:07:09.
#   Batch 4,500  of  5,992.    Elapsed: 5:13:24.
#   Batch 4,600  of  5,992.    Elapsed: 5:19:49.
#   Batch 4,700  of  5,992.    Elapsed: 5:26:38.
#   Batch 4,800  of  5,992.    Elapsed: 5:33:29.
#   Batch 4,900  of  5,992.    Elapsed: 5:40:21.
#   Batch 5,000  of  5,992.    Elapsed: 5:46:57.
#   Batch 5,100  of  5,992.    Elapsed: 5:53:37.
#   Batch 5,200  of  5,992.    Elapsed: 6:00:22.
#   Batch 5,300  of  5,992.    Elapsed: 6:07:05.
#   Batch 5,400  of  5,992.    Elapsed: 6:13:54.
#   Batch 5,500  of  5,992.    Elapsed: 6:20:44.
#   Batch 5,600  of  5,992.    Elapsed: 6:27:34.
#   Batch 5,700  of  5,992.    Elapsed: 6:34:25.
#   Batch 5,800  of  5,992.    Elapsed: 6:41:17.
#   Batch 5,900  of  5,992.    Elapsed: 6:47:28.
#
#   Average training loss: 0.08
#   Training epoch took: 6:53:47
#
# Running Validation...
#   Macro F1 score: 0.80
#   Validation Loss: 0.52
#   Validation took: 0:40:06
#
# ======== Epoch 5 / 5 ========
# Training...
#   Batch   100  of  5,992.    Elapsed: 0:06:50.
#   Batch   200  of  5,992.    Elapsed: 0:13:43.
#   Batch   300  of  5,992.    Elapsed: 0:20:39.
#   Batch   400  of  5,992.    Elapsed: 0:27:23.
#   Batch   500  of  5,992.    Elapsed: 0:34:15.
#   Batch   600  of  5,992.    Elapsed: 0:41:03.
#   Batch   700  of  5,992.    Elapsed: 0:47:40.
#   Batch   800  of  5,992.    Elapsed: 0:52:12.
#   Batch   900  of  5,992.    Elapsed: 0:56:50.
#   Batch 1,000  of  5,992.    Elapsed: 1:01:26.
#   Batch 1,100  of  5,992.    Elapsed: 1:05:58.
#   Batch 1,200  of  5,992.    Elapsed: 1:10:31.
#   Batch 1,300  of  5,992.    Elapsed: 1:15:04.
#   Batch 1,400  of  5,992.    Elapsed: 1:19:39.
#   Batch 1,500  of  5,992.    Elapsed: 1:24:15.
#   Batch 1,600  of  5,992.    Elapsed: 1:28:51.
#   Batch 1,700  of  5,992.    Elapsed: 1:33:26.
#   Batch 1,800  of  5,992.    Elapsed: 1:38:00.
#   Batch 1,900  of  5,992.    Elapsed: 1:42:26.
#   Batch 2,000  of  5,992.    Elapsed: 1:46:49.
#   Batch 2,100  of  5,992.    Elapsed: 1:51:22.
#   Batch 2,200  of  5,992.    Elapsed: 1:55:56.
#   Batch 2,300  of  5,992.    Elapsed: 2:00:29.
#   Batch 2,400  of  5,992.    Elapsed: 2:05:05.
#   Batch 2,500  of  5,992.    Elapsed: 2:09:43.
#   Batch 2,600  of  5,992.    Elapsed: 2:14:15.
#   Batch 2,700  of  5,992.    Elapsed: 2:18:47.
#   Batch 2,800  of  5,992.    Elapsed: 2:23:22.
#   Batch 2,900  of  5,992.    Elapsed: 2:27:57.
#   Batch 3,000  of  5,992.    Elapsed: 2:32:33.
#   Batch 3,100  of  5,992.    Elapsed: 2:37:07.
#   Batch 3,200  of  5,992.    Elapsed: 2:41:42.
#   Batch 3,300  of  5,992.    Elapsed: 2:46:16.
#   Batch 3,400  of  5,992.    Elapsed: 2:50:48.
#   Batch 3,500  of  5,992.    Elapsed: 2:55:21.
#   Batch 3,600  of  5,992.    Elapsed: 2:59:56.
#   Batch 3,700  of  5,992.    Elapsed: 3:04:28.
#   Batch 3,800  of  5,992.    Elapsed: 3:08:59.
#   Batch 3,900  of  5,992.    Elapsed: 3:13:29.
#   Batch 4,000  of  5,992.    Elapsed: 3:18:01.
#   Batch 4,100  of  5,992.    Elapsed: 3:22:26.
#   Batch 4,200  of  5,992.    Elapsed: 3:26:59.
#   Batch 4,300  of  5,992.    Elapsed: 3:31:31.
#   Batch 4,400  of  5,992.    Elapsed: 3:36:03.
#   Batch 4,500  of  5,992.    Elapsed: 3:40:36.
#   Batch 4,600  of  5,992.    Elapsed: 3:45:11.
#   Batch 4,700  of  5,992.    Elapsed: 3:49:44.
#   Batch 4,800  of  5,992.    Elapsed: 3:54:19.
#   Batch 4,900  of  5,992.    Elapsed: 3:58:57.
#   Batch 5,000  of  5,992.    Elapsed: 4:03:32.
#   Batch 5,100  of  5,992.    Elapsed: 4:08:06.
#   Batch 5,200  of  5,992.    Elapsed: 4:12:32.
#   Batch 5,300  of  5,992.    Elapsed: 4:17:06.
#   Batch 5,400  of  5,992.    Elapsed: 4:21:38.
#   Batch 5,500  of  5,992.    Elapsed: 4:26:09.
#   Batch 5,600  of  5,992.    Elapsed: 4:30:43.
#   Batch 5,700  of  5,992.    Elapsed: 4:35:17.
#   Batch 5,800  of  5,992.    Elapsed: 4:39:51.
#   Batch 5,900  of  5,992.    Elapsed: 4:44:23.
#
#   Average training loss: 0.06
#   Training epoch took: 4:48:33
#
# Running Validation...
#   Macro F1 score: 0.81
#   Validation Loss: 0.53
#   Validation took: 0:23:39
#
# Training complete!
# Total training took 1 day, 8:40:52 (h:mm:ss)

# %%
# Look at training summary

df_stats = pd.DataFrame(data=training_stats)
df_stats = df_stats.set_index('epoch')
df_stats
# Out:
#        Training Loss  Valid. Loss  Valid. Macro F1 score. Training Time  \
# epoch
# 1           0.391652     0.517439                0.734776       5:31:06
# 2           0.224337     0.480653                0.786832       5:15:16
# 3           0.136535     0.491524                0.797373       7:03:56
# 4           0.083624     0.523766                0.804942       6:53:47
# 5           0.056176     0.530264                0.808750       4:48:33
#
#       Validation Time
# epoch
# 1             0:35:36
# 2             0:39:29
# 3             0:48:15
# 4             0:40:06
# 5             0:23:39

# %%
# Plot the learning curve

sns.set(style='darkgrid')
# sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

plt.plot(df_stats['Training Loss'], 'b-o', label="Training")
plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation")

plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.xticks(list(range(1,epochs+1)))

plt.show()

# %%
# Restore best model

PATH = "models/longformer" + '_epoch_' + str(5) + '.pt'

#model = LongformerForSequenceClassification.from_pretrained("allenai/longformer-base-4096", problem_type="multi_label_classification", num_labels=13)
#model = DataParallel(model)
#model.to(device)
#optimizer = RAdam(model.parameters(), lr=learning_rate)

checkpoint = torch.load(PATH)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %% [markdown]
# ## 4. Predict on test set
# (Do not use batches, loop through CSRs and aggregate predicted labels)

# %%
# Predict each batch and use logical or for each label

X = list(X_test)
Y = Y_test

model.eval()

predictions = []

i = 0
# Iterate through CSRs
for i in tqdm(range(len(X))):
    # Encode doc
    encoding_dict = split_doc_into_encoding_chunks_with_labels(X[i], Y[i])
    num_chunks = len(encoding_dict['input_ids'])
    
    # Predict each chunk
    logits_list = []
    for c in range(num_chunks):
        input_ids = encoding_dict['input_ids'][c].to(device)
        attention_mask = encoding_dict['attention_mask'][c].to(device)
        # Forward pass
        with torch.no_grad():
            result = model(input_ids.unsqueeze(0),
                           token_type_ids=None,
                           attention_mask=attention_mask.unsqueeze(0),
                           return_dict=True)
        logits = result.logits

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()

        # Store logits
        logits_list.append(logits)

    # Transform logits into labels
    labels_list = torch.round(torch.sigmoid(torch.Tensor(np.concatenate(logits_list, axis=0)))).numpy().astype(int)
    # Set label prediction to 1 if at least one chunk predicted 1, and 0 otherwise
    predicted_label = np.any(labels_list, axis=0).astype(float)
    # Store predictions
    predictions.append(predicted_label)
    i += 1
# Out:
#   0%|          | 0/1308 [00:00<?, ?it/s]

# %%
# Print classification report
print(classification_report(Y_test, predictions))

# Plot confusion matrices for each label
sdgs = [1, 3, 4, 5, 6, 7, 8, 11, 12, 13, 15, 16, 17]
counter = 0
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 22))
plt.subplots_adjust(hspace=0.5)
for ax in axes.flatten():
    if counter <= 12:
        cm = confusion_matrix(true_labels[:, counter], predicted_labels[:, counter])
        sns.heatmap(cm, annot=True, fmt="g", ax=ax, cmap="Greens")
        ax.set_title("SDG " + str(sdgs[counter]))
        ax.set_xlabel("Predicted labels")
        ax.set_ylabel("True labels")
        counter += 1
    else:
        ax.set_visible(False)
        counter += 1
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.83      0.66       156
#            1       0.89      0.93      0.91      1077
#            2       0.86      0.93      0.89      1041
#            3       0.84      0.93      0.89       981
#            4       0.86      0.93      0.89      1011
#            5       0.81      0.92      0.86       958
#            6       0.82      0.94      0.88       899
#            7       0.55      0.81      0.65       153
#            8       0.90      0.93      0.92      1116
#            9       0.76      0.92      0.83       828
#           10       0.67      0.91      0.77       472
#           11       0.82      0.95      0.88       930
#           12       0.55      0.82      0.66       153
#
#    micro avg       0.81      0.92      0.86      9775
#    macro avg       0.76      0.90      0.82      9775
# weighted avg       0.82      0.92      0.87      9775
#  samples avg       0.80      0.91      0.83      9775
